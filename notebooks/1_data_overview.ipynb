# %%
# !pip install kagglehub numpy matplotlib pandas
# Out:
# Requirement already satisfied: kagglehub in /home/margo/A/projects/python/client_activity_forecast/.venv/lib/python3.11/site-packages (0.3.13)
# Collecting numpy
#   Using cached numpy-2.4.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
# Collecting matplotlib
#   Downloading matplotlib-3.10.8-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 1.4 MB/s eta 0:00:0000:0100:010m
# Collecting pandas
#   Using cached pandas-2.3.3-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.8 MB)
# Requirement already satisfied: requests in /home/margo/A/projects/python/client_activity_forecast/.venv/lib/python3.11/site-packages (from kagglehub) (2.32.5)
# Requirement already satisfied: pyyaml in /home/margo/A/projects/python/client_activity_forecast/.venv/lib/python3.11/site-packages (from kagglehub) (6.0.3)
# Requirement already satisfied: packaging in /home/margo/A/projects/python/client_activity_forecast/.venv/lib/python3.11/site-packages (from kagglehub) (25.0)
# Requirement already satisfied: tqdm in /home/margo/A/projects/python/client_activity_forecast/.venv/lib/python3.11/site-packages (from kagglehub) (4.67.1)
# Collecting pyparsing>=3
#   Using cached pyparsing-3.2.5-py3-none-any.whl (113 kB)
# Collecting cycler>=0.10
#   Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.3.3-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (355 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 355.2/355.2 KB 722.5 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: python-dateutil>=2.7 in /home/margo/A/projects/python/client_activity_forecast/.venv/lib/python3.11/site-packages (from matplotlib) (2.9.0.post0)
# Collecting kiwisolver>=1.3.1
#   Downloading kiwisolver-1.4.9-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 1.7 MB/s eta 0:00:0000:0100:010m
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.61.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (5.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 1.3 MB/s eta 0:00:0000:0100:01
# Collecting pillow>=8
#   Using cached pillow-12.0.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (7.0 MB)
# Collecting tzdata>=2022.7
#   Downloading tzdata-2025.3-py2.py3-none-any.whl (348 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 348.5/348.5 KB 478.5 kB/s eta 0:00:00a 0:00:01
# Collecting pytz>=2020.1
#   Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Requirement already satisfied: six>=1.5 in /home/margo/A/projects/python/client_activity_forecast/.venv/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/margo/A/projects/python/client_activity_forecast/.venv/lib/python3.11/site-packages (from requests->kagglehub) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/margo/A/projects/python/client_activity_forecast/.venv/lib/python3.11/site-packages (from requests->kagglehub) (2025.11.12)
# Requirement already satisfied: idna<4,>=2.5 in /home/margo/A/projects/python/client_activity_forecast/.venv/lib/python3.11/site-packages (from requests->kagglehub) (3.11)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/margo/A/projects/python/client_activity_forecast/.venv/lib/python3.11/site-packages (from requests->kagglehub) (3.4.4)
# Installing collected packages: pytz, tzdata, pyparsing, pillow, numpy, kiwisolver, fonttools, cycler, pandas, contourpy, matplotlib
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.61.1 kiwisolver-1.4.9 matplotlib-3.10.8 numpy-2.4.0 pandas-2.3.3 pillow-12.0.0 pyparsing-3.2.5 pytz-2025.2 tzdata-2025.3

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("shivamb/bank-customer-segmentation")

print("Path to dataset files:", path)

# %%
raw_data_path = "../data/raw"

# Создаем папку назначения
# !mkdir -p {raw_data_path}

# Копируем данные
# !cp -r {path}/* {raw_data_path}/

# Проверяем
print("Скопированные файлы:")
# !ls {raw_data_path}/
# Out:
# Скопированные файлы:
# bank_transactions.csv

# %%
import pandas as pd
df = pd.read_csv(raw_data_path + "/bank_transactions.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048567 entries, 0 to 1048566
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   TransactionID            1048567 non-null  object
#  1   CustomerID               1048567 non-null  object
#  2   CustomerDOB              1045170 non-null  object
#  3   CustGender               1047467 non-null  object
#  4   CustLocation             1048416 non-null  object
#  5   CustAccountBalance       1046198 non-null  float64
#  6   TransactionDate          1048567 non-null  object
#  7   TransactionTime          1048567 non-null  int64
#  8   TransactionAmount (INR)  1048567 non-null  float64
# dtypes: float64(2), int64(1), object(6)
# memory usage: 72.0+ MB
