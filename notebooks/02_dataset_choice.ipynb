# %% [markdown]
# # Что обнаружено:
# 1. Данные датасета https://www.kaggle.com/datasets/shivamb/bank-customer-segmentation охватывают всего 2.5 месяца
# 2. У клиентов слишком маленькая история:
#    - 75% клиентов имеют только 1 транзакцию
#    - Медианный период активности клиента = 0 дней
# 3. Невозможно построить модель для предсказания активности за следующий месяц:
#    - Нельзя создать лаги за несколько периодов
#    - Нельзя оценить сезонность/тренды
#    - Невозможно применить временную кросс-валидацию
#
# # Выводы:
# 1. Исходный датасет не пригоден для задачи прогнозирования активности клиентов на следующий месяц.
# 2. Требуется датасет с историей минимум 12+ месяцев.

# %% [markdown]
# # Возможные, подходящие датасеты, которые можно проверить
#
# ## 1 вариант
# https://huggingface.co/datasets/ai-lab/MBD
#
# ## 2 вариант
# https://github.com/thevisgroup/MoneyVis описание тут https://people.cs.nott.ac.uk/blaramee/research/financeVis/firat23moneyVis.pdf
#
# ## Попробуем их быстро оценить

# %% [markdown]
# 1 вариант подошёл, взяли его
